# %%
import sys
from os.path import join as path_join
sys.path.insert(0, path_join("..", "..", ".."))

import pandas as pd
from causality.data.datasets.lalonde import LaLonde


dataframe = LaLonde.as_dataframe()
dataframe.describe()
# Out:
# /home/moritz/novartis/machine_learning/causality/venv/lib/python3.5/site-packages/rpy2/robjects/pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)
#               age        educ       black       hisp     married      nodegr  \
# count  445.000000  445.000000  445.000000  445.00000  445.000000  445.000000
# mean    25.370787   10.195506    0.833708    0.08764    0.168539    0.782022
# std      7.100282    1.792119    0.372762    0.28309    0.374766    0.413337
# min     17.000000    3.000000    0.000000    0.00000    0.000000    0.000000
# 25%     20.000000    9.000000    1.000000    0.00000    0.000000    1.000000
# 50%     24.000000   10.000000    1.000000    0.00000    0.000000    1.000000
# 75%     28.000000   11.000000    1.000000    0.00000    0.000000    1.000000
# ...

# %% [markdown]
# ### Analyzing the Data

# %%
from causality.estimation.causal_forest import CausalForest

dataset = LaLonde.from_r()

train_data, test_data = dataset.split(
    test_fraction=0.3, validation_fraction=None
)


CausalForest().fit(**train_data.asdict()).predict_ate(test_data.covariates)
# Out:
# /home/moritz/novartis/machine_learning/causality/venv/lib/python3.5/site-packages/rpy2/robjects/pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)
# ../../../causality/data/datasets/lalonde.py:38: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   treatment_assignment=data["treat"].as_matrix(),
# ../../../causality/data/datasets/lalonde.py:39: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   observed_outcomes=data["re78"].as_matrix(),
# ../../../causality/data/datasets/lalonde.py:40: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   covariates=covariates.as_matrix()
# 1633.0797441976292
